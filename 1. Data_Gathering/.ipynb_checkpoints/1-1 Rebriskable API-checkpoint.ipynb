# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Rebrickable** (https://rebrickable.com/) is a website that shows which other LEGO sets you can build from the sets and parts you already own. It has established a database with the LEGO Parts, Sets, Colors, and a lot more design-relation information of every official LEGO set. The information is update in real-time and can be accessed through an API.
#
# The following information was gathered and they are up to date as of January 3, 2021:
#
# lego_sets, lego_colors, lego_part_categories, lego_parts, lego_themes, inventories, inventory_minifigs, inventory_parts, inventory_sets.

# %%
# Import required packages
import numpy as np
import pandas as pd
import requests
from bs4 import BeautifulSoup

# For performing regex operations
import re

# For adding delays so that I don't spam requests
import time

import urllib

# %% [markdown]
# #### Sets

# %%
# Load in one of the pages and inspect data structure
# Note that the actual Activation Key is replaced with 'xxxx' below
curl = 'https://rebrickable.com/api/v3/lego/sets/?key=xxxx&page_size=1000&page=17'

# %%
r = requests.get(curl)

# %%
pd.DataFrame(r.json()['results'])
# Out:
#             set_num                                               name  year  \
# 0         SWDVDBD-1                                 The Padawan Menace  2011
# 1      swminifigs-1                     Star Wars Minifig Packs 4-Pack  2000
# 2            SWMP-1                 Star Wars / M&M Mosaic - Promo Set  2005
# 3      TANTIVE-IV-1                                         Tantive IV  2019
# 4    tech007promo-1  Technic Figure Cyber Person Promotional Polyba...  1998
# ..              ...                                                ...   ...
# 99       XMASTREE-1                                     Christmas Tree  2019
# 100         XWING-1                                Mini X-Wing Fighter  2019
# 101         XWING-2                                  X-Wing Trench Run  2019
# 102     YODACHRON-1                    Yoda Chronicles Promotional Set  2013
# 103        ZX8000-1                               ZX 8000 LEGO Sneaker  2020
#
#      theme_id  num_parts                                        set_img_url  \
# 0         501          4  https://cdn.rebrickable.com/media/sets/swdvdbd...
# 1         158          0  https://cdn.rebrickable.com/media/sets/swminif...
# 2         158       5462                                               None
# 3         158         56  https://cdn.rebrickable.com/media/sets/tantive...
# 4           3          1  https://cdn.rebrickable.com/media/sets/tech007...
# ..        ...        ...                                                ...
# 99        410         26  https://cdn.rebrickable.com/media/sets/xmastre...
# 100       158         60  https://cdn.rebrickable.com/media/sets/xwing-1...
# 101       158         52  https://cdn.rebrickable.com/media/sets/xwing-2...
# 102       158        413  https://cdn.rebrickable.com/media/sets/yodachr...
# 103       501          0  https://cdn.rebrickable.com/media/sets/zx8000-...
#
#                                                set_url  \
# 0    https://rebrickable.com/sets/SWDVDBD-1/the-pad...
# 1    https://rebrickable.com/sets/swminifigs-1/star...
# 2    https://rebrickable.com/sets/SWMP-1/star-wars-...
# 3    https://rebrickable.com/sets/TANTIVE-IV-1/tant...
# 4    https://rebrickable.com/sets/tech007promo-1/te...
# ..                                                 ...
# 99   https://rebrickable.com/sets/XMASTREE-1/christ...
# 100  https://rebrickable.com/sets/XWING-1/mini-x-wi...
# 101  https://rebrickable.com/sets/XWING-2/x-wing-tr...
# 102  https://rebrickable.com/sets/YODACHRON-1/yoda-...
# 103  https://rebrickable.com/sets/ZX8000-1/zx-8000-...
#
#                 last_modified_dt
# 0    2015-05-23T01:30:31.308999Z
# 1    2019-11-05T11:37:27.275635Z
# 2    2019-11-05T16:34:42.542127Z
# 3    2019-11-05T16:40:48.088428Z
# 4    2013-10-25T17:49:10.772434Z
# ..                           ...
# 99   2019-11-29T07:42:16.643436Z
# 100  2019-11-03T15:08:31.000303Z
# 101  2019-11-03T15:15:29.879154Z
# 102  2019-06-01T22:24:48.768032Z
# 103  2020-10-03T08:46:28.162198Z
#
# [104 rows x 8 columns]

# %%
#Loop through all 17 pages, scrape contents associated with key 'results'
# Note that the actual Activation Key is replaced with 'xxxx' below
set_list = []
for page in range(1,18):
    url = f'https://rebrickable.com/api/v3/lego/sets/?key=xxxx&page_size=1000&page={page}'
    result = requests.get(url).json()['results']
    set_list += result

# %%
lego_sets = pd.DataFrame(set_list).iloc[:, 0:5]
lego_sets.head()
# Out:
#   set_num                        name  year  theme_id  num_parts
# 0   001-1                       Gears  1965         1         43
# 1  0011-2           Town Mini-Figures  1978        84         12
# 2  0011-3  Castle 2 for 1 Bonus Offer  1987       199          0
# 3  0012-1          Space Mini-Figures  1979       143         12
# 4  0013-1          Space Mini-Figures  1979       143         12

# %%
lego_sets.to_csv('lego_sets_01_03_2021.csv',index=False)

# %% [markdown]
# #### Themes

# %%
# Note that the actual Activation Key is replaced with 'xxxx' below
turl = 'https://rebrickable.com/api/v3/lego/themes/?key=xxxx&page_size=1000&page=1'
t = requests.get(turl)
pd.DataFrame(t.json()['results'])
# Out:
#       id  parent_id                            name
# 0      1        NaN                         Technic
# 1      2        1.0                  Arctic Technic
# 2      3        1.0                     Competition
# 3      4        1.0                  Expert Builder
# 4      5        1.0                           Model
# ..   ...        ...                             ...
# 592  708      697.0           The LEGO Batman Movie
# 593  709        NaN                        LEGO Art
# 594  710      207.0                    Harry Potter
# 595  711      535.0  The LEGO Batman Movie Series 2
# 596  712      535.0           Series 21 Minifigures
#
# [597 rows x 3 columns]

# %%
lego_themes = pd.DataFrame(t.json()['results'])
lego_themes.to_csv('lego_themes_01_03_2021.csv',index=False)

# %% [markdown]
# #### Colors

# %%
# Note that the actual Activation Key is replaced with 'xxxx' below
curl = 'https://rebrickable.com/api/v3/lego/colors/?key=xxxx&page_size=1000&page=1'
c = requests.get(curl)
pd.DataFrame(c.json()['results'])
# Out:
#        id                      name     rgb  is_trans  \
# 0      -1                 [Unknown]  0033B2     False
# 1       0                     Black  05131D     False
# 2       1                      Blue  0055BF     False
# 3       2                     Green  237841     False
# 4       3            Dark Turquoise  008F9B     False
# ..    ...                       ...     ...       ...
# 181  1055          Trans-Clear Opal  FCFCFC      True
# 182  1056          Trans-Brown Opal  583927      True
# 183  1057  Trans-Light Bright Green  C9E788      True
# 184  1058         Trans-Light Green  94E5AB      True
# 185  9999      [No Color/Any Color]  05131D     False
#
#                                           external_ids
# 0    {'BrickOwl': {'ext_ids': [0, 28, 29, 30, 31, 3...
# 1    {'LDraw': {'ext_ids': [256, 0], 'ext_descrs': ...
# 2    {'BrickLink': {'ext_ids': [7], 'ext_descrs': [...
# 3    {'BrickLink': {'ext_ids': [6], 'ext_descrs': [...
# 4    {'BrickLink': {'ext_ids': [39], 'ext_descrs': ...
# ..                                                 ...
# 181  {'LEGO': {'ext_ids': [360], 'ext_descrs': [['T...
# 182  {'LEGO': {'ext_ids': [360], 'ext_descrs': [['T...
# 183  {'LEGO': {'ext_ids': [227], 'ext_descrs': [['T...
# 184  {'LEGO': {'ext_ids': [285], 'ext_descrs': [['T...
# 185  {'BrickLink': {'ext_ids': [0], 'ext_descrs': [...
#
# [186 rows x 5 columns]

# %%
lego_colors = pd.DataFrame(c.json()['results'])
lego_colors.to_csv('lego_colors_01_03_2021.csv',index=False)

# %% [markdown]
# #### Parts

# %%
# Load in one of the pages and inspect data structure
# Note that the actual Activation Key is replaced with 'xxxx' below
purl = 'https://rebrickable.com/api/v3/lego/parts/?key=xxxx&page_size=1000&page=38'
p = requests.get(purl)
pd.DataFrame(p.json()['results'])
# Out:
#           part_num                                               name  \
# 0          upn0022          Plant, Tree Granulated Bush with 2 Trunks
# 1          upn0023            Neckwear Poncho, Tattered and Pixelated
# 2          upn0024  Neckwear Apron with Magenta Butterflies and Po...
# 3    upn0025pr0001   Sail, 9 x 11, with 3 Holes and Red Stripes Print
# 4    upn0025pr0002  Sail, 9 x 11, with 3 Holes and Blue Stripes Print
# ..             ...                                                ...
# 539    znapupn0002              Znap Connector 3 x 3 - 4 way B (Beam)
# 540    znapupn0003                     Znap Connector 1 x 3 - 2 way A
# 541    znapupn0004                                Znap Beam 3, 1 Hole
# 542    znapupn0005            Znap Connector 3 x 3 - 4 way C (Closed)
# 543    znapupn0006                  Wheel 68mm Znap Propeller (9 x 2)
#
#      part_cat_id                                           part_url  \
# 0             28  https://rebrickable.com/parts/upn0022/plant-tr...
# 1             38  https://rebrickable.com/parts/upn0023/neckwear...
# 2             38  https://rebrickable.com/parts/upn0024/neckwear...
# 3             38  https://rebrickable.com/parts/upn0025pr0001/sa...
# 4             38  https://rebrickable.com/parts/upn0025pr0002/sa...
# ..           ...                                                ...
# 539           43  https://rebrickable.com/parts/znapupn0002/znap...
# 540           43  https://rebrickable.com/parts/znapupn0003/znap...
# 541           43  https://rebrickable.com/parts/znapupn0004/znap...
# 542           43  https://rebrickable.com/parts/znapupn0005/znap...
# 543           29  https://rebrickable.com/parts/znapupn0006/whee...
#
#                                           part_img_url  \
# 0    https://cdn.rebrickable.com/media/parts/photos...
# 1    https://cdn.rebrickable.com/media/parts/photos...
# 2    https://cdn.rebrickable.com/media/parts/photos...
# 3    https://cdn.rebrickable.com/media/parts/photos...
# 4    https://cdn.rebrickable.com/media/parts/photos...
# ..                                                 ...
# 539  https://cdn.rebrickable.com/media/parts/photos...
# 540  https://cdn.rebrickable.com/media/parts/photos...
# 541  https://cdn.rebrickable.com/media/parts/ldraw/...
# 542  https://cdn.rebrickable.com/media/parts/photos...
# 543  https://cdn.rebrickable.com/media/parts/photos...
#
#                                           external_ids print_of
# 0    {'BrickLink': ['GTBush'], 'BrickOwl': ['577085']}     None
# 1    {'BrickLink': ['bb0846'], 'BrickOwl': ['775852']}     None
# 2                        {'BrickLink': ['bb0613pb01']}     None
# 3    {'BrickLink': ['sailbb24'], 'BrickOwl': ['8137...  upn0025
# 4    {'BrickLink': ['sailbb27'], 'BrickOwl': ['1745...  upn0025
# ..                                                 ...      ...
# 539      {'BrickLink': ['zbb013'], 'LDraw': ['32211']}     None
# 540                          {'BrickLink': ['zbb014']}     None
# 541      {'BrickLink': ['zbb015'], 'LDraw': ['32210']}     None
# 542                          {'BrickLink': ['zbb018']}     None
# 543                          {'BrickLink': ['zbb022']}     None
#
# [544 rows x 7 columns]

# %%
pd.DataFrame(p.json()['results']).iloc[:,0:3]
# Out:
#     part_num                                               name  part_cat_id
# 0     003434                        Sticker Sheet for Set 653-1           58
# 1     004219  Sticker Sheet for Set 939-1 with flags for AU, IE           58
# 2     004229                        Sticker Sheet for Set 295-1           58
# 3     004284                        Sticker Sheet for Set 723-2           58
# 4     004285                        Sticker Sheet for Set 725-2           58
# ..       ...                                                ...          ...
# 995   120070                       Poster, U.S.S. Constellation           17
# 996    12017  Duplo Train Locomotive Front with Silver Headl...            4
# 997   120317          Instruction Manual, Blacktron Super Model           17
# 998    12044                       Duplo Animal Lion Adult Male            4
# 999    12053             Duplo Animal Cow with Pink Udder Print            4
#
# [1000 rows x 3 columns]

# %%
#Loop through all 38 pages, scrape contents associated with key 'results'
# Note that the actual Activation Key is replaced with 'xxxx' below
parts_list = []
for page in range(1,39):
    url = f'https://rebrickable.com/api/v3/lego/parts/?key=xxxx&page_size=1000&page={page}'
    result = requests.get(url).json()['results']
    parts_list += result

# %%
lego_parts = pd.DataFrame(parts_list).iloc[:, 0:3]
print(lego_parts.shape)
lego_parts.head()
# Out:
# (37154, 3)
#   part_num                                               name  part_cat_id
# 0   003434                        Sticker Sheet for Set 653-1           58
# 1   004219  Sticker Sheet for Set 939-1 with flags for AU, IE           58
# 2   004229                        Sticker Sheet for Set 295-1           58
# 3   004284                        Sticker Sheet for Set 723-2           58
# 4   004285                        Sticker Sheet for Set 725-2           58

# %%
lego_parts.to_csv('lego_parts_01_03_2021.csv',index=False)

# %% [markdown]
# #### Parts Categories

# %%
# Note that the actual Activation Key is replaced with 'xxxx' below
pcurl = 'https://rebrickable.com/api/v3/lego/part_categories/?key=xxxx&page_size=1000&page=1'
pc = requests.get(pcurl)
pd.DataFrame(pc.json()['results'])
# Out:
#     id                     name  part_count
# 0    1               Baseplates         234
# 1    3            Bricks Sloped         500
# 2    4  Duplo, Quatro and Primo        3385
# 3    5           Bricks Special         138
# 4    6            Bricks Wedged         249
# ..  ..                      ...         ...
# 60  63      Minidoll Upper Body         334
# 61  64      Minidoll Lower Body         234
# 62  65         Minifig Headwear        1513
# 63  66                  Modulex         219
# 64  67   Tiles Round and Curved         430
#
# [65 rows x 3 columns]

# %%
lego_part_categories = pd.DataFrame(pc.json()['results'])
lego_part_categories.to_csv('lego_part_categories_01_03_2021.csv',index=False)

# %% [markdown]
# #### minifigs

# %%
# Note that the actual Activation Key is replaced with 'xxxx' below
imurl = 'https://rebrickable.com/api/v3/lego/minifigs/?key=xxxx&page_size=1000&page=1'
im = requests.get(imurl)
pd.DataFrame(im.json()['results'])
# Out:
#         set_num                                               name  num_parts  \
# 0    fig-000001                                 Toy Store Employee          4
# 1    fig-000002                                       Customer Kid          4
# 2    fig-000003                              Assassin Droid, White          8
# 3    fig-000004                                       Basic Figure          4
# 4    fig-000005                    Captain America with Short Legs          3
# ..          ...                                                ...        ...
# 995  fig-001011  Shogun, Armor and Helmet with Horn, Blue and B...          6
# 996  fig-001012                                       Farmer (CMF)          4
# 997  fig-001013                          Red Skull with Short Legs          3
# 998  fig-001014                                          Astronaut          6
# 999  fig-001015                                            Painter          4
#
#                                            set_img_url  \
# 0    https://cdn.rebrickable.com/media/sets/fig-000...
# 1    https://cdn.rebrickable.com/media/sets/fig-000...
# 2    https://cdn.rebrickable.com/media/sets/fig-000...
# 3    https://cdn.rebrickable.com/media/sets/fig-000...
# 4    https://cdn.rebrickable.com/media/sets/fig-000...
# ..                                                 ...
# 995  https://cdn.rebrickable.com/media/sets/fig-001...
# 996                                               None
# 997  https://cdn.rebrickable.com/media/sets/fig-001...
# 998  https://cdn.rebrickable.com/media/sets/fig-001...
# 999  https://cdn.rebrickable.com/media/sets/fig-001...
#
#                                                set_url  \
# 0    https://rebrickable.com/minifigs/fig-000001/to...
# 1    https://rebrickable.com/minifigs/fig-000002/cu...
# 2    https://rebrickable.com/minifigs/fig-000003/as...
# 3    https://rebrickable.com/minifigs/fig-000004/ba...
# 4    https://rebrickable.com/minifigs/fig-000005/ca...
# ..                                                 ...
# 995  https://rebrickable.com/minifigs/fig-001011/sh...
# 996  https://rebrickable.com/minifigs/fig-001012/fa...
# 997  https://rebrickable.com/minifigs/fig-001013/re...
# 998  https://rebrickable.com/minifigs/fig-001014/as...
# 999  https://rebrickable.com/minifigs/fig-001015/pa...
#
#                 last_modified_dt
# 0    2020-05-27T21:47:00.694941Z
# 1    2020-05-27T21:47:11.750470Z
# 2    2020-06-20T00:49:06.811000Z
# 3    2020-04-09T06:06:08.127005Z
# 4    2020-04-23T00:09:38.460466Z
# ..                           ...
# 995  2020-05-02T19:26:25.437850Z
# 996  2020-09-10T15:10:13.935333Z
# 997  2020-04-23T00:09:00.583930Z
# 998  2020-05-31T17:59:15.299295Z
# 999  2020-05-31T10:13:20.257542Z
#
# [1000 rows x 6 columns]
